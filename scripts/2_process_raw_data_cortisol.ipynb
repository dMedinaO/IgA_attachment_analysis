# %% [markdown]
# - Handling warnings

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# - Loading modules

# %%
import pandas as pd

# %% [markdown]
# - Read cortisol dataset

# %%
df_cortisol = pd.read_csv("../raw_data/cortisol/raw_data_measures.csv")
df_cortisol
# Out:
#    Sample  Cortisol (pg/mL) Attachment
# 0      38              4.21     Secure
# 1      16              3.59     Secure
# 2      32             22.75     Secure
# 3       1              5.62   Insecure
# 4       7              1.83   Insecure
# 5      39              3.07   Insecure
# 6       5              2.28     Secure
# 7      63              7.08   Insecure
# 8      27              2.26     Secure
# 9      23              4.76     Secure

# %%
df_cortisol.shape
# Out:
# (10, 3)

# %% [markdown]
# - Read processed IgA dataset

# %%
df_processed_data = pd.read_csv("../processed_data/1_processed_data_IgA.csv")
df_processed_data.head(5)
# Out:
#    ID  Gender  IgA_Average_Morning  IgA_Average_Afternoon  Average_Difference  \
# 0   1    Male            21.765240              28.368055            6.602815
# 1   4    Male            28.473065              50.881961           22.408896
# 2   5  Female           161.424693              46.867951         -114.556742
# 3   7  Female            24.173487              35.942378           14.343241
# 4  11    Male            78.013279             382.715268          345.590046
#
#   Attachment
# 0   Insecure
# 1     Secure
# 2     Secure
# 3   Insecure
# 4    Unknown

# %% [markdown]
# - Making merge and deleting NaN values

# %%
df_merge = df_cortisol.merge(right=df_processed_data, left_on="Sample", right_on="ID", how="left")
df_merge
# Out:
#    Sample  Cortisol (pg/mL) Attachment_x    ID  Gender  IgA_Average_Morning  \
# 0      38              4.21       Secure   NaN     NaN                  NaN
# 1      16              3.59       Secure  16.0  Female            57.476955
# 2      32             22.75       Secure  32.0    Male            32.565326
# 3       1              5.62     Insecure   1.0    Male            21.765240
# 4       7              1.83     Insecure   7.0  Female            24.173487
# 5      39              3.07     Insecure   NaN     NaN                  NaN
# 6       5              2.28       Secure   5.0  Female           161.424693
# 7      63              7.08     Insecure  63.0    Male            26.219626
# 8      27              2.26       Secure  27.0  Female            43.637360
# 9      23              4.76       Secure  23.0  Female            80.824884
#
#    IgA_Average_Afternoon  Average_Difference Attachment_y
# 0                    NaN                 NaN          NaN
# 1              73.891936           16.414980       Secure
# 2              44.611069           12.045743       Secure
# 3              28.368055            6.602815     Insecure
# 4              35.942378           14.343241     Insecure
# 5                    NaN                 NaN          NaN
# 6              46.867951         -114.556742       Secure
# 7              20.066422           -6.153204     Insecure
# 8              37.759187          -15.388331       Secure
# 9              47.632842          -33.192041       Secure

# %%
df_merge = df_merge.dropna()
df_merge
# Out:
#    Sample  Cortisol (pg/mL) Attachment_x    ID  Gender  IgA_Average_Morning  \
# 1      16              3.59       Secure  16.0  Female            57.476955
# 2      32             22.75       Secure  32.0    Male            32.565326
# 3       1              5.62     Insecure   1.0    Male            21.765240
# 4       7              1.83     Insecure   7.0  Female            24.173487
# 6       5              2.28       Secure   5.0  Female           161.424693
# 7      63              7.08     Insecure  63.0    Male            26.219626
# 8      27              2.26       Secure  27.0  Female            43.637360
# 9      23              4.76       Secure  23.0  Female            80.824884
#
#    IgA_Average_Afternoon  Average_Difference Attachment_y
# 1              73.891936           16.414980       Secure
# 2              44.611069           12.045743       Secure
# 3              28.368055            6.602815     Insecure
# 4              35.942378           14.343241     Insecure
# 6              46.867951         -114.556742       Secure
# 7              20.066422           -6.153204     Insecure
# 8              37.759187          -15.388331       Secure
# 9              47.632842          -33.192041       Secure

# %% [markdown]
# - Processing merge dataset

# %%
df_merge.columns
# Out:
# Index(['Sample', 'Cortisol (pg/mL)', 'Attachment_x', 'ID', 'Gender',
#        'IgA_Average_Morning', 'IgA_Average_Afternoon', 'Average_Difference',
#        'Attachment_y'],
#       dtype='object')

# %%
df_merge = df_merge[['ID', 'Gender', 'IgA_Average_Morning', 
                    'IgA_Average_Afternoon', 'Average_Difference', 
                    'Cortisol (pg/mL)', 'Attachment_y']]
df_merge.columns = ['ID', 'Gender', 'IgA_Average_Morning', 
                    'IgA_Average_Afternoon', 'Average_Difference', 
                    'Cortisol (pg/mL)', 'Attachment']
df_merge
# Out:
#      ID  Gender  IgA_Average_Morning  IgA_Average_Afternoon  \
# 1  16.0  Female            57.476955              73.891936
# 2  32.0    Male            32.565326              44.611069
# 3   1.0    Male            21.765240              28.368055
# 4   7.0  Female            24.173487              35.942378
# 6   5.0  Female           161.424693              46.867951
# 7  63.0    Male            26.219626              20.066422
# 8  27.0  Female            43.637360              37.759187
# 9  23.0  Female            80.824884              47.632842
#
#    Average_Difference  Cortisol (pg/mL) Attachment
# 1           16.414980              3.59     Secure
# 2           12.045743             22.75     Secure
# 3            6.602815              5.62   Insecure
# 4           14.343241              1.83   Insecure
# 6         -114.556742              2.28     Secure
# 7           -6.153204              7.08   Insecure
# 8          -15.388331              2.26     Secure
# 9          -33.192041              4.76     Secure

# %% [markdown]
# - Checking some statistics

# %%
df_merge[["Cortisol (pg/mL)", "Attachment"]].groupby(by=["Attachment"]).mean()
# Out:
#             Cortisol (pg/mL)
# Attachment
# Insecure            4.843333
# Secure              7.128000

# %%
df_merge[["Cortisol (pg/mL)", "Attachment"]].groupby(by=["Attachment"]).median()
# Out:
#             Cortisol (pg/mL)
# Attachment
# Insecure                5.62
# Secure                  3.59

# %% [markdown]
# - Exporting processed dataset

# %%
df_merge.to_csv("../processed_data/2_processed_data_cortisol.csv", index=False)

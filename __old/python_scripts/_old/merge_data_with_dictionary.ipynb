# %%
import pandas as pd
import json

df_data = pd.read_csv("../full_analysis/all_data_merge.csv")

# %%
count_null_values = []

for column in df_data.columns:
    data_columns = df_data[column].isna()

    count=0

    for element in data_columns:
        if element == True:
            count+=1
    percentage = count*100/len(df_data)

    row = [column, count, percentage]

    count_null_values.append(row)

df_counts = pd.DataFrame(count_null_values, columns=['column', 'null', 'null_percentage'])
df_counts = df_counts.sort_values(by=['null_percentage'], ascending=False)
df_counts
# Out:
#                            column  null  null_percentage
# 307                      ASQ_6_15    34        97.142857
# 311                      ASQ_6_19    34        97.142857
# 66   relative_8_educational_level    34        97.142857
# 65          relativa_8_occupation    34        97.142857
# 64      relative_8_marital_status    34        97.142857
# ..                            ...   ...              ...
# 142                ADS_CHILD_TA_2     0         0.000000
# 141                  ADS_CHILD_TA     0         0.000000
# 140                   ADS_CHILD_V     0         0.000000
# 139                 ADS_CHILD_M_2     0         0.000000
# 379                    ADS2i_2020     0         0.000000
#
# [380 rows x 3 columns]

# %%
df_counts.describe()
# Out:
#              null  null_percentage
# count  380.000000       380.000000
# mean     7.268421        20.766917
# std     11.337776        32.393647
# min      0.000000         0.000000
# 25%      0.000000         0.000000
# 50%      0.000000         0.000000
# 75%     10.000000        28.571429
# max     34.000000        97.142857

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.style.use("seaborn-v0_8-white")
plt.rc('axes', grid=False, facecolor="white")
plt.rcParams.update({'font.size': 14})

sns.boxplot(x=df_counts['null_percentage'])
# Out:
# <AxesSubplot: xlabel='null_percentage'>

# %%
columns_with_null_values = []

for index in df_counts.index:
    if df_counts['null_percentage'][index]> 28.571429:#esto es el q3
        columns_with_null_values.append(df_counts['column'][index])

# %%
columns_with_id = ['id_name', 'm1', 'm2', 'm3', 'm4']

# %%
non_informative_columns = []

for column in df_data.columns:
    if column not in columns_with_id:
        unique_values = df_data[column].unique()

        if len(unique_values) == 1 or len(unique_values) == len(df_data):
            non_informative_columns.append(column)

# %%
columns_to_filter = columns_with_null_values + non_informative_columns
columns_to_filter.append('id_name')

df_ignored_columns = df_data[columns_to_filter]

df_measures = [['id_name', 'm1', 'm2', 'm3', 'm4']]

columns_to_use = [column for column in df_data.columns if column not in columns_to_filter and column not in columns_with_id]
columns_to_use.append('id_name')

df_with_values_to_cluster = df_data[columns_to_use]

# %%
df_with_values_to_cluster.to_csv("../full_analysis/data_with_values_to_use.csv", index=False)

# %%
def check_proportions(name_column, dataset):

    unique_values = dataset[name_column].unique()
    dict_values = {}

    for value in unique_values:
        filter_data = dataset.loc[dataset[name_column] == value]
        dict_values.update({str(value) : len(filter_data)})
    dict_response = {name_column: dict_values}
    return dict_response, len(unique_values)

# %%
distribution_len_unique = []

dict_values_proportions = []

for column in df_with_values_to_cluster.columns:
    dict_proportion, len_unique = check_proportions(column, df_with_values_to_cluster)
    dict_values_proportions.append(dict_proportion)
    distribution_len_unique.append(len_unique)

dict_values_proportions
# Out:
# [{'BienestarV1': {'5.0': 8, 'nan': 0, '4.0': 20, '3.0': 3}},
#  {'BienestarV2': {'4.0': 24, 'nan': 0, '5.0': 5, '3.0': 2}},
#  {'BienestarAv': {'4.5': 7, 'nan': 0, '4.0': 19, '5.0': 2, '3.5': 3}},
#  {'Género_bebé': {'1': 15, '0': 20}},
#  {'Edad_bebé_1': {'5': 2,
#    '10': 6,
#    '12': 4,
#    '8': 4,
#    '11': 3,
#    '13': 1,
#    '6': 2,
#    '14': 2,
#    '7': 4,
#    '9': 6,
#    '3': 1}},
#  {'Etnia_bebé': {'1': 13, '0': 22}},
#  {'Grupo_étnico_bebé': {'4': 12, '0': 22, '10': 1}},
#  {'Cuidado_alt_previo': {'0': 34, '1': 1}},
#  {'Razón_entrada_SC': {'1': 20,
#    '7': 4,
#    '3': 1,
#    '4': 2,
#    '5': 6,
#    '6': 1,
#    '2': 1}},
#  {'Jornada_SalaC': {'3': 31, '1': 4}},
#  {'Otro_cuidado': {'1': 10, '0': 25}},
#  {'Tipo_cuidado_alt': {'1': 6, '0': 25, '2': 3, '3': 1}},
#  {'Relación_cuidador_bebé': {'1': 34, '5': 1}},
#  {'Edad_cuidador_1': {'22': 1,
#    '33': 3,
#    '19': 2,
#    '26': 3,
#    '24': 4,
#    '58': 1,
#    '30': 2,
#    '29': 1,
#    '17': 2,
#    '27': 3,
#    '36': 3,
#    '25': 3,
#    '18': 2,
#    '41': 1,
#    '34': 1,
#    '38': 1,
#    '31': 1,
#    '20': 1}},
#  {'Edad_cuidador_2': {'22.0': 1,
#    '33.0': 3,
#    'nan': 0,
#    '26.0': 3,
#    '24.0': 4,
#    '19.0': 1,
#    '58.0': 1,
#    '30.0': 2,
#    '29.0': 1,
#    '17.0': 1,
#    '27.0': 2,
#    '36.0': 2,
#    '28.0': 1,
#    '18.0': 3,
#    '25.0': 3,
#    '42.0': 1,
#    '34.0': 1,
#    '37.0': 1,
#    '31.0': 1,
#    '20.0': 1}},
#  {'Estado_civ_cuidador_pr': {'1': 20, '2': 8, '6': 7}},
#  {'Estado_civ_cat': {'0': 20, '1': 15}},
#  {'Ocupación_cuidador_pr': {'3': 3,
#    '4': 5,
#    '11': 3,
#    '5': 10,
#    '8': 1,
#    '12': 7,
#    '9': 1,
#    '10': 2,
#    '2': 2,
#    '7': 1}},
#  {'occupationdic': {'1': 27, '0': 8}},
#  {'altcaregiverdic': {'1': 10, '0': 25}},
#  {'Nivel_educ_cuidador_pr': {'6': 6,
#    '7': 3,
#    '5': 7,
#    '3': 3,
#    '4': 14,
#    '2': 1,
#    '1': 1}},
#  {'Etnia_cuidador_pr': {'1': 8, '0': 27}},
#  {'Grupo_étnico_cuidador_pr': {'4': 7, '0': 27, '10': 1}},
#  {'NSE_familia': {'2': 3,
#    '10': 3,
#    '4': 3,
#    '5': 7,
#    '9': 5,
#    '3': 5,
#    '7': 3,
#    '6': 2,
#    '8': 4}},
#  {'N_familiares': {'4': 7, '2': 14, '5': 1, '3': 12, '7': 1}},
#  {'Familiar1_RelaciónNiño': {'5': 9,
#    '8': 3,
#    '2': 20,
#    '1': 1,
#    '10': 1,
#    '6': 1}},
#  {'Familiar1_EstadoCiv': {'2': 11, '1': 14, '5': 1, '6': 7, '4': 2}},
#  {'Familiar1_Ocupación': {'2': 5,
#    '10': 2,
#    '13': 3,
#    '4': 5,
#    '5': 13,
#    '3': 4,
#    '1': 1,
#    '12': 1,
#    '9': 1}},
#  {'Familiar1_NivelEduc': {'4': 14,
#    '9': 1,
#    '6': 6,
#    '1': 1,
#    '5': 4,
#    '3': 4,
#    '7': 4,
#    '2': 1}},
#  {'Familiar1_GrupoEtnico': {'0': 27, '4': 5, '1': 2, '10': 1}},
#  {'HO_1': {'0': 10, '1': 25}},
#  {'HO_2': {'1': 31, '0': 4}},
#  {'HO_3': {'1': 33, '0': 2}},
#  {'HO_4': {'1': 25, '0': 10}},
#  {'HO_5': {'1': 34, '0': 1}},
#  {'HO_6': {'1': 34, '0': 1}},
#  {'HO_8': {'1': 26, '0': 9}},
#  {'HO_9': {'1': 33, '0': 2}},
#  {'HO_10': {'1': 33, '0': 2}},
#  {'HO_11': {'1': 30, '0': 5}},
#  {'HO_12': {'0': 16, '1': 19}},
#  {'HO_13': {'1': 22, '0': 13}},
#  {'HO_14': {'1': 27, '0': 8}},
#  {'HO_15': {'1': 30, '0': 5}},
#  {'HO_16': {'1': 32, '0': 3}},
#  {'HO_17': {'1': 31, '0': 4}},
#  {'HO_18': {'1': 19, '0': 16}},
#  {'HO_19': {'0': 23, '1': 12}},
#  {'HO_20': {'1': 26, '0': 9}},
#  {'HO_21': {'1': 33, '0': 2}},
#  {'HO_22': {'1': 29, '0': 6}},
#  {'HO_24': {'1': 31, '0': 4}},
#  {'HO_25': {'0': 15, '1': 20}},
#  {'HO_26': {'0': 14, '1': 21}},
#  {'HO_27': {'0': 12, '1': 23}},
#  {'HO_28': {'1': 33, '0': 2}},
#  {'HO_29': {'1': 26, '0': 9}},
#  {'HO_30': {'1': 31, '0': 4}},
#  {'HO_31': {'0': 13, '1': 22}},
#  {'HO_32': {'0': 19, '1': 16}},
#  {'HO_33': {'1': 32, '0': 3}},
#  {'HO_34': {'1': 16, '0': 19}},
#  {'HO_35': {'1': 31, '0': 4}},
#  {'HO_36': {'1': 25, '0': 10}},
#  {'HO_37': {'1': 16, '0': 19}},
#  {'HO_38': {'0': 24, '1': 11}},
#  {'HO_39': {'0': 25, '1': 10}},
#  {'HO_40': {'1': 33, '0': 2}},
#  {'HO_41': {'0': 9, '1': 26}},
#  {'HO_42': {'0': 26, '1': 9}},
#  {'HO_43': {'0': 8, '1': 27}},
#  {'HO_44': {'1': 33, '0': 2}},
#  {'HO_45': {'0': 28, '1': 7}},
#  {'IT_HOME_Responsividad': {'10': 13,
#    '11': 11,
#    '8': 4,
#    '9': 4,
#    '6': 1,
#    '7': 2}},
#  {'IT_HOME_Aceptación': {'6': 7,
#    '7': 9,
#    '4': 1,
#    '1': 2,
#    '5': 8,
#    '3': 3,
#    '0': 1,
#    '8': 4}},
#  {'IT_HOME_Organización': {'5': 13, '4': 8, '6': 12, '2': 1, '3': 1}},
#  {'IT_HOME_Provisión_de_materiales': {'5': 9,
#    '8': 7,
#    '6': 6,
#    '9': 4,
#    '3': 2,
#    '4': 3,
#    '7': 4}},
#  {'IT_HOME_Implicación_materna': {'4': 11,
#    '5': 5,
#    '6': 3,
#    '1': 2,
#    '2': 5,
#    '3': 9}},
#  {'IT_HOME_Variedad': {'1': 4, '2': 6, '3': 16, '5': 2, '4': 7}},
#  {'IT_HOME_TOTAL': {'31': 4,
#    '38': 4,
#    '39': 3,
#    '25': 1,
#    '27': 3,
#    '33': 4,
#    '36': 2,
#    '29': 4,
#    '26': 1,
#    '24': 1,
#    '37': 1,
#    '40': 1,
#    '34': 2,
#    '41': 1,
#    '30': 1,
#    '32': 1,
#    '35': 1}},
#  {'BSI_1': {'1': 34, '2': 1}},
#  {'BSI_2': {'2': 8, '1': 22, '4': 2, '5': 1, '3': 2}},
#  {'BSI_3': {'2': 11, '1': 19, '3': 4, '5': 1}},
#  {'BSI_4': {'1': 31, '3': 1, '5': 1, '2': 2}},
#  {'BSI_5': {'1': 20, '2': 10, '5': 2, '3': 3}},
#  {'BSI_6': {'2': 4, '1': 30, '5': 1}},
#  {'BSI_TOTAL': {'1.5': 3,
#    '1.33333333333333': 7,
#    '1.66666666666667': 6,
#    '1.0': 11,
#    '1.16666666666667': 4,
#    '0.833333333333333': 1,
#    '2.5': 1,
#    '4.5': 1,
#    '1.83333333333333': 1}},
#  {'EEP_1_in': {'5': 3,
#    '8': 2,
#    '4': 3,
#    '3': 2,
#    '10': 17,
#    '0': 3,
#    '9': 3,
#    '7': 1,
#    '6': 1}},
#  {'EEP_2': {'10': 20, '9': 9, '3': 1, '6': 2, '7': 1, '5': 1, '8': 1}},
#  {'EEP_3_in': {'10': 23,
#    '9': 3,
#    '2': 1,
#    '5': 3,
#    '3': 1,
#    '1': 1,
#    '6': 1,
#    '4': 1,
#    '7': 1}},
#  {'EEP_4': {'8': 3, '10': 19, '9': 6, '7': 4, '1': 1, '0': 2}},
#  {'EEP_5_in': {'10': 23,
#    '6': 1,
#    '0': 2,
#    '3': 1,
#    '2': 1,
#    '5': 1,
#    '9': 3,
#    '8': 2,
#    '1': 1}},
#  {'EEP_6_in': {'3': 1,
#    '10': 20,
#    '8': 3,
#    '2': 2,
#    '5': 1,
#    '0': 1,
#    '9': 3,
#    '7': 3,
#    '1': 1}},
#  {'EEP_7_in': {'8': 4,
#    '7': 4,
#    '10': 12,
#    '6': 1,
#    '3': 3,
#    '9': 4,
#    '2': 4,
#    '5': 2,
#    '4': 1}},
#  {'EEP_8_in': {'10': 24,
#    '3': 1,
#    '8': 3,
#    '2': 1,
#    '7': 2,
#    '5': 1,
#    '0': 1,
#    '1': 1,
#    '9': 1}},
#  {'EEP_9_in': {'10': 22,
#    '5': 3,
#    '3': 2,
#    '8': 2,
#    '1': 1,
#    '2': 2,
#    '9': 2,
#    '0': 1}},
#  {'EEP_10': {'10': 32, '9': 3}},
#  {'EEP_TOTAL': {'8.4': 4,
#    '8.1': 1,
#    '9.4': 3,
#    '6.8': 1,
#    '6.4': 1,
#    '8.7': 1,
#    '8.9': 1,
#    '8.2': 1,
#    '7.7': 1,
#    '9.6': 1,
#    '5.3': 2,
#    '10.0': 4,
#    '8.6': 1,
#    '9.0': 3,
#    '9.9': 2,
#    '6.0': 1,
#    '9.8': 1,
#    '8.8': 1,
#    '8.3': 2,
#    '7.1': 1,
#    '5.6': 1,
#    '5.9': 1}},
#  {'ADS_CHILD_M': {'2': 8, '3': 19, '4': 8}},
#  {'ADS_CHILD_M_2': {'2': 8, '1': 19, '4': 8}},
#  {'ADS_CHILD_V': {'2': 6, '4': 8, '3': 21}},
#  {'ADS_CHILD_TA': {'2': 10, '1': 2, '3': 14, '4': 9}},
#  {'ADS_CHILD_TA_2': {'2': 10, '1': 16, '4': 9}},
#  {'ADS_CHILD_SA': {'2': 4, '1': 1, '4': 8, '3': 15, '999': 7}},
#  {'ADS_CHILD_A': {'3': 20, '4': 13, '1': 1, '5': 1}},
#  {'ADS_CHILD_P': {'2': 7, '1': 2, '3': 19, '4': 7}},
#  {'ADS_MAIN_CAREGIVER_M': {'3': 12, '4': 20, '2': 3}},
#  {'ADS_MAIN_CAREGIVER_V': {'2': 9, '3': 12, '4': 13, '1': 1}},
#  {'ADS_MAIN_CAREGIVER_TA': {'2': 9, '3': 14, '4': 8, '1': 4}},
#  {'ADS_MAIN_CAREGIVER_SA': {'3': 15, '4': 7, '2': 6, '999': 6, '1': 1}},
#  {'ADS_MAIN_CAREGIVER_A': {'2': 5, '3': 20, '4': 10}},
#  {'ADS_MAIN_CAREGIVER_P': {'3': 17, '4': 15, '2': 3}},
#  {'ADS_MAIN_CAREGIVER_M_2': {'1': 12, '4': 20, '2': 3}},
#  {'ADS_MAIN_CAREGIVER_V_2': {'2': 9, '1': 13, '4': 13}},
#  {'ADS_MAIN_CAREGIVER_TA_2': {'2': 9, '3': 14, '4': 8, '1': 4}},
#  {'ADS_MAIN_CAREGIVER_SA_2': {'3': 15, '4': 7, '2': 6, '999': 6, '1': 1}},
#  {'ADS_MAIN_CAREGIVER_A_2': {'2': 5, '1': 20, '4': 10}},
#  {'ADS_MAIN_CAREGIVER_P_2': {'3': 17, '4': 15, '2': 3}},
#  {'Secure_bebé': {'1': 2, '2': 2, '4': 6, '3': 2, '5': 7, '0': 3, '6': 13}},
#  {'Insecure_bebé': {'5': 2, '4': 3, '2': 5, '3': 1, '1': 7, '0': 17}},
#  {'secure_bebe2': {'1': 2, '2': 3, '3': 11, '4': 8, '0': 1, '6': 5, '5': 5}},
#  {'insecure_bebe2': {'5': 2, '4': 4, '3': 6, '2': 13, '0': 5, '1': 5}},
#  {'mirada_dic': {'0': 27, '1': 8}},
#  {'vocalizacion_dic': {'0': 6, '1': 29}},
#  {'tacto_dic': {'0': 26, '1': 9}},
#  {'sosten_dic': {'0.0': 5, '1.0': 23, 'nan': 0}},
#  {'afecto_dic': {'1': 34, '0': 1}},
#  {'proximidad_dic': {'0': 9, '1': 26}},
#  {'attachment2_ads': {'0': 12, '1': 23}},
#  {'Attachment_ads': {'0': 8, '1': 27}},
#  {'sensitivity': {'3': 3, '6': 15, '2': 1, '5': 6, '4': 4, '1': 4, '0': 2}},
#  {'sensitivity2': {'2': 3, '3': 5, '5': 6, '1': 8, '4': 6, '0': 1, '6': 6}},
#  {'Sala_cuna': {'8': 3,
#    '4': 4,
#    '11': 1,
#    '12': 4,
#    '2': 5,
#    '9': 3,
#    '1': 3,
#    '5': 3,
#    '13': 3,
#    '6': 5,
#    '10': 1}},
#  {'Edad_bebé_2': {'7.0': 3,
#    '10.0': 4,
#    'nan': 0,
#    '12.0': 3,
#    '9.0': 6,
#    '13.0': 3,
#    '11.0': 6,
#    '14.0': 1,
#    '15.0': 2,
#    '8.0': 2,
#    '1.0': 1,
#    '4.0': 1,
#    '6.0': 1}},
#  {'asistio_sc': {'1': 33, '0': 2}},
#  {'Día_asist_vid1_EN': {'3.0': 3,
#    '5.0': 3,
#    'nan': 0,
#    '7.0': 7,
#    '8.0': 2,
#    '9.0': 2,
#    '4.0': 3,
#    '10.0': 1,
#    '11.0': 3,
#    '1.0': 1,
#    '6.0': 2,
#    '18.0': 1,
#    '13.0': 1,
#    '15.0': 1}},
#  {'Adultos_asist_vid1_EN': {'3.0': 9,
#    '5.0': 12,
#    'nan': 0,
#    '4.0': 6,
#    '8.0': 1,
#    '2.0': 1,
#    '7.0': 3}},
#  {'Niños_asist_vid1_EN': {'9.0': 7,
#    '11.0': 7,
#    'nan': 0,
#    '12.0': 1,
#    '15.0': 2,
#    '18.0': 2,
#    '5.0': 1,
#    '8.0': 2,
#    '13.0': 5,
#    '7.0': 1,
#    '6.0': 1,
#    '14.0': 1,
#    '3.0': 1}},
#  {'Adultos_asist_vid2_EN': {'3.0': 8,
#    'nan': 0,
#    '4.0': 8,
#    '5.0': 11,
#    '8.0': 1,
#    '2.0': 1,
#    '7.0': 2}},
#  {'Niños_asist_vid2_EN': {'9.0': 9,
#    'nan': 0,
#    '8.0': 2,
#    '7.0': 2,
#    '12.0': 3,
#    '4.0': 6,
#    '10.0': 1,
#    '13.0': 3,
#    '6.0': 2,
#    '11.0': 2,
#    '5.0': 1}},
#  {'Frec_1_EN_vid1': {'0.0': 18,
#    'nan': 0,
#    '151.0': 1,
#    '1.0': 1,
#    '27.0': 1,
#    '31.0': 1,
#    '96.0': 1,
#    '203.0': 1,
#    '43.0': 1,
#    '3.0': 2,
#    '125.0': 1,
#    '13.0': 1,
#    '2.0': 1,
#    '20.0': 1,
#    '17.0': 1,
#    '22.0': 1}},
#  {'Frec_2_EN_vid1': {'0.0': 10,
#    '4.0': 2,
#    'nan': 0,
#    '65.0': 1,
#    '2.0': 2,
#    '27.0': 1,
#    '63.0': 1,
#    '97.0': 1,
#    '60.0': 1,
#    '41.0': 1,
#    '56.0': 1,
#    '86.0': 2,
#    '22.0': 1,
#    '24.0': 1,
#    '1.0': 1,
#    '3.0': 1,
#    '23.0': 1,
#    '6.0': 2,
#    '7.0': 1,
#    '26.0': 1,
#    '59.0': 1}},
#  {'Frec_3_EN_vid1': {'259.0': 3,
#    '187.0': 2,
#    'nan': 0,
#    '163.0': 1,
#    '41.0': 1,
#    '249.0': 1,
#    '168.0': 2,
#    '2.0': 1,
#    '107.0': 1,
#    '122.0': 1,
#    '262.0': 1,
#    '52.0': 1,
#    '27.0': 1,
#    '125.0': 1,
#    '243.0': 1,
#    '195.0': 1,
#    '70.0': 1,
#    '201.0': 1,
#    '165.0': 1,
#    '150.0': 1,
#    '266.0': 1,
#    '127.0': 1,
#    '104.0': 1,
#    '254.0': 1,
#    '216.0': 1,
#    '101.0': 1,
#    '265.0': 1,
#    '287.0': 1,
#    '171.0': 1,
#    '105.0': 1}},
#  {'Frec_4_EN_vid1': {'26.0': 1,
#    '6.0': 1,
#    'nan': 0,
#    '0.0': 14,
#    '15.0': 1,
#    '3.0': 3,
#    '30.0': 1,
#    '18.0': 1,
#    '11.0': 1,
#    '55.0': 1,
#    '13.0': 1,
#    '8.0': 1,
#    '10.0': 1,
#    '1.0': 1,
#    '47.0': 1,
#    '5.0': 1,
#    '25.0': 1,
#    '4.0': 1,
#    '9.0': 1}},
#  {'Frec_5_EN_vid1': {'3.0': 2,
#    '0.0': 27,
#    'nan': 0,
#    '2.0': 1,
#    '1.0': 1,
#    '5.0': 1,
#    '6.0': 1}},
#  {'Frec_6_EN_vid1': {'12.0': 1,
#    '103.0': 2,
#    'nan': 0,
#    '137.0': 1,
#    '43.0': 1,
#    '32.0': 1,
#    '100.0': 1,
#    '208.0': 1,
#    '62.0': 1,
#    '22.0': 1,
#    '8.0': 1,
#    '4.0': 1,
#    '210.0': 1,
#    '46.0': 1,
#    '14.0': 1,
#    '94.0': 1,
#    '81.0': 1,
#    '40.0': 1,
#    '99.0': 1,
#    '38.0': 1,
#    '86.0': 1,
#    '31.0': 3,
#    '125.0': 1,
#    '171.0': 1,
#    '184.0': 1,
#    '42.0': 1,
#    '45.0': 1,
#    '153.0': 1,
#    '7.0': 1,
#    '53.0': 1,
#    '78.0': 1}},
#  {'Frec_1_EN_vid2': {'0.0': 24,
#    'nan': 0,
#    '28.0': 1,
#    '1.0': 2,
#    '17.0': 1,
#    '4.0': 1,
#    '37.0': 1,
#    '3.0': 1,
#    '8.0': 1}},
#  {'Frec_2_EN_vid2': {'0.0': 17,
#    'nan': 0,
#    '38.0': 1,
#    '3.0': 2,
#    '5.0': 3,
#    '187.0': 1,
#    '126.0': 1,
#    '1.0': 2,
#    '7.0': 1,
#    '13.0': 1,
#    '28.0': 1,
#    '12.0': 1,
#    '42.0': 1}},
#  {'Frec_3_EN_vid2': {'260.0': 1,
#    'nan': 0,
#    '284.0': 1,
#    '180.0': 1,
#    '251.0': 2,
#    '107.0': 2,
#    '237.0': 1,
#    '50.0': 1,
#    '222.0': 2,
#    '201.0': 1,
#    '176.0': 1,
#    '25.0': 1,
#    '289.0': 1,
#    '295.0': 1,
#    '238.0': 1,
#    '219.0': 2,
#    '278.0': 1,
#    '213.0': 1,
#    '299.0': 1,
#    '234.0': 1,
#    '167.0': 1,
#    '106.0': 1,
#    '243.0': 1,
#    '263.0': 1,
#    '280.0': 1,
#    '186.0': 1,
#    '293.0': 2,
#    '37.0': 1}},
#  {'Frec_4_EN_vid2': {'37.0': 1,
#    'nan': 0,
#    '0.0': 20,
#    '15.0': 2,
#    '12.0': 1,
#    '29.0': 1,
#    '3.0': 1,
#    '9.0': 1,
#    '6.0': 1,
#    '23.0': 2,
#    '49.0': 1,
#    '2.0': 1}},
#  {'Frec_5_EN_vid2': {'1.0': 1, 'nan': 0, '0.0': 28, '2.0': 1, '3.0': 2}},
#  {'Frec_6_EN_vid2': {'2.0': 1,
#    'nan': 0,
#    '16.0': 2,
#    '54.0': 1,
#    '31.0': 3,
#    '183.0': 1,
#    '58.0': 1,
#    '62.0': 1,
#    '59.0': 1,
#    '67.0': 1,
#    '124.0': 1,
#    '132.0': 1,
#    '7.0': 3,
#    '5.0': 1,
#    '46.0': 1,
#    '72.0': 1,
#    '87.0': 1,
#    '1.0': 1,
#    '27.0': 1,
#    '81.0': 1,
#    '129.0': 1,
#    '57.0': 1,
#    '11.0': 1,
#    '8.0': 1,
#    '184.0': 1,
#    '263.0': 1,
#    '191.0': 1,
#    '76.0': 1}},
#  {'Prop_1y2_vid1': {'0.0': 9,
#    '0.0203045685279188': 1,
#    'nan': 0,
#    '0.840466926070039': 1,
#    '0.0074626865671641': 1,
#    '0.14': 1,
#    '0.978260869565217': 1,
#    '0.53781512605042': 1,
#    '0.561151079136691': 1,
#    '0.824324324324324': 1,
#    '0.622222222222222': 1,
#    '0.507874015748032': 1,
#    '0.0874125874125874': 1,
#    '0.680365296803653': 1,
#    '0.0038461538461538': 1,
#    '0.0114503816793893': 1,
#    '0.168224299065421': 1,
#    '0.0342857142857143': 1,
#    '0.0155038759689923': 2,
#    '0.0603448275862069': 1,
#    '0.0313725490196078': 1,
#    '0.312925170068027': 1,
#    '0.0102389078498294': 1,
#    '0.307692307692308': 1,
#    '0.486486486486487': 1}},
#  {'Prop_1y2_vid2': {'0.0': 16,
#    'nan': 0,
#    '0.268292682926829': 1,
#    '0.0111524163568773': 1,
#    '0.0206611570247934': 1,
#    '0.789915966386555': 1,
#    '0.020746887966805': 1,
#    '0.851190476190476': 1,
#    '0.0034129692832764': 1,
#    '0.0275590551181102': 1,
#    '0.0394736842105263': 1,
#    '0.0476190476190476': 1,
#    '0.0136986301369863': 1,
#    '0.380116959064327': 1,
#    '0.0103806228373702': 1,
#    '0.0410958904109589': 1,
#    '0.185873605947955': 1,
#    '0.0089285714285714': 1}},
#  {'Prop_3_vid1': {'0.899305555555556': 1,
#    '0.949238578680203': 1,
#    'nan': 0,
#    '1.0': 1,
#    '0.159533073929961': 1,
#    '0.92910447761194': 1,
#    '0.84': 1,
#    '0.0217391304347826': 1,
#    '0.449579831932773': 1,
#    '0.438848920863309': 1,
#    '0.897260273972603': 1,
#    '0.175675675675676': 1,
#    '0.3': 1,
#    '0.492125984251969': 1,
#    '0.84965034965035': 1,
#    '0.946601941747573': 1,
#    '0.319634703196347': 1,
#    '0.773076923076923': 1,
#    '0.930348258706468': 1,
#    '0.988549618320611': 1,
#    '0.771028037383178': 1,
#    '0.962825278810409': 1,
#    '0.96': 1,
#    '0.761421319796954': 1,
#    '0.988847583643123': 1,
#    '0.984496124031008': 2,
#    '0.896551724137931': 1,
#    '0.847058823529412': 1,
#    '0.687074829931973': 1,
#    '0.985130111524164': 1,
#    '0.979522184300341': 1,
#    '0.692307692307692': 1,
#    '0.472972972972973': 1}},
#  {'Prop_3_vid2': {'0.87248322147651': 1,
#    'nan': 0,
#    '1.0': 9,
#    '0.731707317073171': 1,
#    '0.933085501858736': 2,
#    '0.914529914529915': 1,
#    '0.979338842975207': 1,
#    '0.210084033613445': 1,
#    '0.921161825726141': 1,
#    '0.862660944206009': 1,
#    '0.148809523809524': 1,
#    '0.986348122866894': 1,
#    '0.937007874015748': 1,
#    '0.960526315789474': 1,
#    '0.97887323943662': 1,
#    '0.857142857142857': 1,
#    '0.762557077625571': 1,
#    '0.619883040935673': 1,
#    '0.910034602076125': 1,
#    '0.958904109589041': 1,
#    '1.60344827586207': 1,
#    '0.981651376146789': 1,
#    '0.814126394052045': 1,
#    '0.991071428571429': 1}},
#  {'Prop_4y5_vid1': {'0.100694444444444': 1,
#    '0.0304568527918782': 1,
#    'nan': 0,
#    '0.0': 14,
#    '0.0634328358208955': 1,
#    '0.0126050420168067': 1,
#    '0.102739726027397': 1,
#    '0.0629370629370629': 1,
#    '0.0533980582524272': 1,
#    '0.223076923076923': 1,
#    '0.0696517412935323': 1,
#    '0.0607476635514019': 1,
#    '0.0371747211895911': 1,
#    '0.0057142857142857': 1,
#    '0.238578680203046': 1,
#    '0.0111524163568773': 1,
#    '0.0431034482758621': 1,
#    '0.12156862745098': 1,
#    '0.0148698884758364': 1,
#    '0.0102389078498294': 1,
#    '0.0405405405405405': 1}},
#  {'Prop_4y5_vid2': {'0.12751677852349': 1,
#    'nan': 0,
#    '0.0': 20,
#    '0.0557620817843866': 2,
#    '0.0580912863070539': 1,
#    '0.137339055793991': 1,
#    '0.0102389078498294': 1,
#    '0.0354330708661417': 1,
#    '0.0211267605633803': 1,
#    '0.0952380952380952': 1,
#    '0.223744292237443': 1,
#    '0.0795847750865052': 1,
#    '0.018348623853211': 1}},
#  {'Edad_joven_ITERS': {'6': 3,
#    '10': 9,
#    '19': 1,
#    '11': 4,
#    '8': 6,
#    '18': 6,
#    '17': 3,
#    '9': 3}},
#  {'Edad_viejo_ITERS': {'17': 8,
#    '26': 4,
#    '27': 1,
#    '18': 9,
#    '25': 3,
#    '24': 6,
#    '21': 3,
#    '19': 1}},
#  {'Número_adultos': {'3': 8, '4': 17, '2': 5, '5': 5}},
#  {'Num_niños_inscritos': {'14': 4, '20': 16, '15': 4, '13': 5, '17': 6}},
#  {'Num_niños_max': {'14': 13, '20': 19, '17': 3}},
#  {'Num_niños_observados': {'7': 4,
#    '11': 13,
#    '13': 1,
#    '10': 11,
#    '17': 3,
#    '14': 3}},
#  {'Edad_educadora': {'39': 3,
#    '45': 4,
#    '50': 5,
#    '40': 8,
#    '36': 3,
#    '52': 3,
#    '28': 3,
#    '53': 5,
#    '51': 1}},
#  {'Años_servicio': {'8': 3,
#    '22': 4,
#    '27': 2,
#    '26': 4,
#    '12': 5,
#    '10': 3,
#    '32': 3,
#    '4': 3,
#    '9': 3,
#    '30': 5}},
#  {'Tiempo_salacuna': {'4.0': 4,
#    '0.3': 4,
#    '10.0': 9,
#    '1.0': 11,
#    '3.0': 4,
#    '5.0': 3}},
#  {'ITERS_1': {'4': 12, '7': 14, '2': 9}},
#  {'ITERS_2': {'2': 24, '6': 3, '1': 8}},
#  {'ITERS_3': {'4': 14, '6': 4, '3': 17}},
#  {'ITERS_4': {'4': 25, '7': 4, '3': 6}},
#  {'ITERS_5': {'4': 14, '2': 12, '3': 4, '6': 5}},
#  {'ITERS_6': {'2': 23, '4': 5, '7': 7}},
#  {'ITERS_7': {'4': 6, '1': 14, '2': 15}},
#  {'ITERS_8': {'4': 4, '3': 13, '2': 18}},
#  {'ITERS_9': {'2': 15, '4': 1, '1': 16, '3': 3}},
#  {'ITERS_10': {'2': 32, '1': 3}},
#  {'ITERS_11': {'2': 13, '4': 14, '1': 8}},
#  {'ITERS_12': {'6': 9, '7': 19, '2': 1, '1': 6}},
#  {'ITERS_13': {'4': 13, '6': 4, '7': 18}},
#  {'ITERS_14': {'3': 7, '4': 9, '1': 16, '2': 3}},
#  {'ITERS_15': {'4': 22, '6': 1, '2': 8, '1': 3, '7': 1}},
#  {'ITERS_16': {'1': 16, '2': 19}},
#  {'ITERS_17': {'4': 20, '2': 4, '7': 6, '1': 5}},
#  {'ITERS_18': {'2': 19, '4': 9, '6': 3, '5': 3, '7': 1}},
#  {'ITERS_19': {'1': 15, '5': 17, '2': 3}},
#  {'ITERS_20': {'1': 3, '4': 20, '7': 1, '2': 11}},
#  {'ITERS_21': {'999': 18, '1': 14, '2': 3}},
#  {'ITERS_22': {'2': 15, '1': 16, '3': 4}},
#  {'ITERS_24': {'2': 27, '1': 8}},
#  {'ITERS_25': {'6': 3, '7': 24, '4': 8}},
#  {'ITERS_26': {'5': 11, '4': 10, '6': 13, '7': 1}},
#  {'ITERS_27': {'7': 32, '6': 3}},
#  {'ITERS_28': {'2': 8, '6': 5, '4': 14, '1': 3, '5': 5}},
#  {'ITERS_29': {'4': 27, '1': 8}},
#  {'ITERS_30': {'2': 30, '7': 1, '1': 4}},
#  {'ITERS_31': {'3': 17, '4': 7, '2': 8, '6': 3}},
#  {'ITERS_spaceandfurnishings': {'3.6': 8,
#    '4.8': 4,
#    '4.0': 1,
#    '3.0': 9,
#    '3.8': 6,
#    '4.2': 3,
#    '3.2': 3,
#    '3.4': 1}},
#  {'ITERS_personalcareandroutines': {'2.66666666666667': 4,
#    '2.33333333333333': 4,
#    '3.0': 1,
#    '2.0': 7,
#    '2.16666666666667': 10,
#    '3.33333333333333': 3,
#    '2.83333333333333': 3,
#    '1.5': 3}},
#  {'ITERS_listeningandtalking': {'3.5': 3,
#    '4.5': 4,
#    '5.5': 9,
#    '4.0': 9,
#    '2.5': 7,
#    '3.0': 3}},
#  {'ITERS_escucharyhablarsindoce': {'3.5': 3,
#    '4.5': 4,
#    '5.5': 9,
#    '4.0': 9,
#    '2.5': 7,
#    '3.0': 3}},
#  {'ITERS_activities': {'2.125': 10,
#    '3.125': 4,
#    '3.75': 1,
#    '3.0': 5,
#    '4.0': 6,
#    '1.875': 3,
#    '1.75': 5,
#    '4.25': 1}},
#  {'ITERS_interaction': {'5.0': 3,
#    '6.0': 16,
#    '6.5': 1,
#    '4.75': 5,
#    '5.75': 3,
#    '4.0': 3,
#    '5.25': 3,
#    '6.25': 1}},
#  {'ITERS_programandstructure': {'3.0': 9,
#    '3.33333333333333': 7,
#    '4.66666666666667': 1,
#    '2.66666666666667': 7,
#    '1.66666666666667': 5,
#    '4.0': 3,
#    '2.0': 3}},
#  {'ITERS_Total': {'3.10714285714286': 3,
#    '3.68965517241379': 4,
#    '4.13793103448276': 1,
#    '3.0': 4,
#    '3.21428571428571': 5,
#    '3.27586206896552': 3,
#    '3.55172413793103': 3,
#    '3.37931034482759': 3,
#    '2.93103448275862': 3,
#    '2.96428571428571': 5,
#    '3.78571428571429': 1}},
#  {'Ratio_ITERS': {'2.33333333333333': 4,
#    '2.75': 8,
#    '4.33333333333333': 1,
#    '5.0': 5,
#    '4.25': 3,
#    '3.5': 3,
#    '3.33333333333333': 3,
#    '2.5': 3,
#    '2.2': 5}},
#  {'Rango_ITERS': {'2': 27, '1': 8}},
#  {'nombre_sala_cuna_puq': {'8': 3,
#    '4': 4,
#    '11': 1,
#    '12': 4,
#    '2': 5,
#    '9': 3,
#    '1': 3,
#    '5': 3,
#    '13': 3,
#    '6': 5,
#    '10': 1}},
#  {'cis_sens': {'4.0': 3,
#    '3.8': 9,
#    '3.9': 5,
#    '2.2': 3,
#    '2.1': 3,
#    '1.4': 3,
#    '1.5': 3,
#    '2.6': 5,
#    '3.0': 1}},
#  {'cis_harsh': {'4.0': 18,
#    '3.0': 3,
#    '3.33333333333333': 3,
#    '3.44444444444444': 3,
#    '3.55555555555556': 3,
#    '3.88888888888889': 5}},
#  {'cis_detach': {'4.0': 23, '3.0': 3, '3.75': 3, '2.0': 3, '1.75': 3}},
#  {'cis_permis': {'3.0': 8,
#    '4.0': 4,
#    '2.0': 5,
#    '3.33333333333333': 6,
#    '2.33333333333333': 6,
#    '2.66666666666667': 6}},
#  {'cis_total_mean': {'3.88461538461538': 3,
#    '3.80769230769231': 4,
#    '3.84615384615385': 1,
#    '3.96153846153846': 4,
#    '3.69230769230769': 5,
#    '2.73076923076923': 3,
#    '2.92307692307692': 3,
#    '2.30769230769231': 3,
#    '2.34615384615385': 3,
#    '3.26923076923077': 5,
#    '3.46153846153846': 1}},
#  {'Ratio_vid1': {'3.0': 4,
#    '2.75': 3,
#    'nan': 0,
#    '2.25': 2,
#    '4.5': 2,
#    '3.75': 1,
#    '6.0': 2,
#    '5.0': 1,
#    '1.25': 1,
#    '5.5': 2,
#    '2.66666666666667': 1,
#    '3.25': 3,
#    '2.6': 2,
#    '3.5': 1,
#    '2.0': 2,
#    '2.2': 2,
#    '2.8': 1,
#    '0.75': 1}},
#  {'Ratio_vid2': {'3.0': 2,
#    'nan': 0,
#    '2.66666666666667': 2,
#    '2.25': 5,
#    '4.5': 3,
#    '1.75': 1,
#    '4.0': 2,
#    '1.0': 4,
#    '1.33333333333333': 1,
#    '2.5': 1,
#    '2.6': 3,
#    '2.0': 2,
#    '2.2': 2,
#    '1.5': 1,
#    '3.5': 1,
#    '1.66666666666667': 1}},
#  {'Fecha_SSP': {'2016-11-26': 2,
#    '2016-08-25': 2,
#    '2016-12-05': 1,
#    '2016-09-07': 1,
#    'nan': 0,
#    '2016-10-06': 1,
#    '2016-09-08': 2,
#    '2016-10-21': 1,
#    '2016-12-10': 1,
#    '2016-09-21': 2,
#    '2016-08-29': 1,
#    '2016-08-27': 1,
#    '2016-08-26': 1,
#    '2016-09-06': 1,
#    '2016-09-03': 1,
#    '2016-12-03': 1,
#    '2016-09-15': 1,
#    '2016-11-25': 1,
#    '2016-09-10': 1,
#    '2016-09-02': 1,
#    '2016-09-30': 1,
#    '2016-09-01': 1,
#    '2016-12-17': 1,
#    '2016-10-07': 1}},
#  {'apego_SSP': {'3.0': 1, '1.0': 18, '2.0': 8, 'nan': 0}},
#  {'Apego_dic_ADS': {'0': 12, '1': 23}},
#  {'Apego_dic_SSP': {'0.0': 9, '1.0': 18, 'nan': 0}},
#  {'change_attachment': {'0.0': 20, '2.0': 3, 'nan': 0, '1.0': 4}},
#  {'poschange_attachment': {'0.0': 24, '1.0': 3, 'nan': 0}},
#  {'negchange_attachment': {'0.0': 23, 'nan': 0, '1.0': 4}},
#  {'Edad_bebé_5': {'15.0': 5,
#    '16.0': 7,
#    '14.0': 3,
#    '18.0': 3,
#    'nan': 0,
#    '17.0': 4,
#    '21.0': 3,
#    '20.0': 1,
#    '19.0': 1}},
#  {'Edad_madre_ssp': {'23.0': 1,
#    '34.0': 2,
#    '20.0': 2,
#    '27.0': 2,
#    'nan': 0,
#    '25.0': 3,
#    '30.0': 1,
#    '29.0': 1,
#    '28.0': 2,
#    '37.0': 1,
#    '18.0': 1,
#    '26.0': 2,
#    '19.0': 2,
#    '42.0': 1,
#    '35.0': 1,
#    '31.0': 1,
#    '36.0': 1,
#    '39.0': 1,
#    '24.0': 1,
#    '32.0': 1}},
#  {'sensitivity_ADS_rec': {'2': 3,
#    '3': 5,
#    '5': 6,
#    '1': 8,
#    '4': 6,
#    '0': 1,
#    '6': 6}},
#  {'Filtro_Sin_Respuesta': {'1': 31, '0': 4}},
#  {'Prop_negativas_total': {'0.0': 6,
#    'nan': 0,
#    '0.554379804498434': 1,
#    '0.0093075514620207': 1,
#    '0.07': 1,
#    '0.499461013295005': 1,
#    '0.663865546218487': 1,
#    '0.290948983551748': 1,
#    '0.412162162162162': 1,
#    '0.736706349206349': 1,
#    '0.255643492515654': 1,
#    '0.0437062937062937': 1,
#    '0.0137795275590551': 1,
#    '0.35991949050709': 1,
#    '0.0019230769230769': 1,
#    '0.0057251908396946': 1,
#    '0.107921673342234': 1,
#    '0.0068493150684931': 1,
#    '0.207201336675021': 1,
#    '0.0051903114186851': 1,
#    '0.0282998831899756': 1,
#    '0.0301724137931035': 1,
#    '0.0077519379844961': 1,
#    '0.0156862745098039': 1,
#    '0.156462585034014': 1,
#    '0.0051194539249146': 1,
#    '0.246782956820132': 1,
#    '0.247707528957529': 1}},
#  {'Prop_neutras_total': {'0.885894388516033': 1,
#    'nan': 0,
#    '1.0': 1,
#    '0.445620195501566': 1,
#    '0.931094989735338': 1,
#    '0.877264957264957': 1,
#    '0.500538986704995': 1,
#    '0.329831932773109': 1,
#    '0.680005373294725': 1,
#    '0.879960609089306': 1,
#    '0.587837837837838': 1,
#    '0.224404761904762': 1,
#    '0.739237053559431': 1,
#    '0.924825174825175': 1,
#    '0.94180490788166': 1,
#    '0.64008050949291': 1,
#    '0.875975081256772': 1,
#    '0.965174129353234': 1,
#    '0.994274809160305': 1,
#    '0.814085447263017': 1,
#    '0.86269117821799': 1,
#    '0.789941520467836': 1,
#    '0.880710659898477': 1,
#    '0.949441092859624': 1,
#    '0.971700116810024': 1,
#    '1.25': 1,
#    '0.992248062015504': 1,
#    '0.923529411764706': 1,
#    '0.843537414965986': 1,
#    '0.95910780669145': 1,
#    '0.980586780223565': 1,
#    '0.753217043179868': 1,
#    '0.732022200772201': 1}},
#  {'Prop_positivas_total': {'0.114105611483967': 1,
#    'nan': 0,
#    '0.0': 12,
#    '0.0595974588026411': 1,
#    '0.0063025210084033': 1,
#    '0.029045643153527': 1,
#    '0.120039390910694': 1,
#    '0.0051194539249146': 1,
#    '0.0314685314685315': 1,
#    '0.0444155645592845': 1,
#    '0.122101841820152': 1,
#    '0.0348258706467662': 1,
#    '0.0779928793947486': 1,
#    '0.130459506713517': 1,
#    '0.0028571428571428': 1,
#    '0.119289340101523': 1,
#    '0.0453685957216913': 1,
#    '0.021551724137931': 1,
#    '0.0607843137254902': 1,
#    '0.0353159851301115': 1,
#    '0.0142937658515202': 1,
#    '0.0202702702702703': 1}},
#  {'filter_$': {'1.0': 31, 'nan': 0}},
#  {'outliers': {'0': 2, '1': 33}},
#  {'Sum_emocneg': {'0.0': 6,
#    'nan': 0,
#    '282.0': 1,
#    '5.0': 1,
#    '28.0': 1,
#    '95.0': 1,
#    '316.0': 1,
#    '161.0': 1,
#    '244.0': 1,
#    '199.0': 1,
#    '130.0': 1,
#    '25.0': 1,
#    '7.0': 2,
#    '158.0': 1,
#    '1.0': 1,
#    '3.0': 4,
#    '49.0': 1,
#    '71.0': 1,
#    '14.0': 1,
#    '4.0': 1,
#    '8.0': 1,
#    '46.0': 1,
#    '126.0': 1,
#    '110.0': 1}},
#  {'Sum_emocpos': {'67.0': 1,
#    'nan': 0,
#    '0.0': 12,
#    '32.0': 1,
#    '3.0': 2,
#    '14.0': 2,
#    '62.0': 1,
#    '18.0': 1,
#    '20.0': 1,
#    '64.0': 1,
#    '39.0': 1,
#    '59.0': 1,
#    '1.0': 1,
#    '47.0': 1,
#    '26.0': 1,
#    '5.0': 2,
#    '31.0': 1,
#    '19.0': 1,
#    '9.0': 1}},
#  {'Muestra_saliva': {'1.0': 34, 'nan': 0}},
#  {'Act_fisica_1': {'0.0': 24, '1.0': 7, 'nan': 0}},
#  {'Act_fisica_2': {'0.0': 30, '1.0': 1, 'nan': 0}},
#  {'Act_fisica_3': {'0.0': 21, 'nan': 0, '1.0': 10}},
#  {'Act_fisica_4': {'0.0': 29, '1.0': 2, 'nan': 0}},
#  {'Siesta_1': {'0.0': 31, 'nan': 0}},
#  {'Siesta_2': {'1.0': 28, '0.0': 3, 'nan': 0}},
#  {'Siesta_3': {'0.0': 31, 'nan': 0}},
#  {'Siesta_4': {'1.0': 27, 'nan': 0, '0.0': 4}},
#  {'Medicamentos_1': {'0.0': 27, 'nan': 0, '1.0': 4}},
#  {'Medicamentos_2': {'0.0': 29, 'nan': 0, '1.0': 2}},
#  {'Medicamentos_3': {'0.0': 29, 'nan': 0, '1.0': 2}},
#  {'Medicamentos_4': {'0.0': 27, 'nan': 0, '1.0': 4}},
#  {'Herida_bucal_1': {'0.0': 30, 'nan': 0, '1.0': 1}},
#  {'Herida_bucal_2': {'0.0': 28, 'nan': 0, '1.0': 3}},
#  {'Herida_bucal_3': {'0.0': 29, '1.0': 2, 'nan': 0}},
#  {'Herida_bucal_4': {'0.0': 28, 'nan': 0, '1.0': 3}},
#  {'Cambio_rutina': {'nan': 0, '0.0': 16, '1.0': 10}},
#  {'Asiste_jardin': {'nan': 0, '1.0': 25, '0.0': 1}},
#  {'Mismo_jardin': {'nan': 0, '1.0': 22, '0.0': 3}},
#  {'Asistio_regular_jardin': {'nan': 0, '1.0': 20, '0.0': 6}},
#  {'Hospitalización': {'nan': 0, '0.0': 22, '1.0': 4}},
#  {'Diag_enfermedad': {'nan': 0, '1.0': 8, '0.0': 18}},
#  {'edad_igA1': {'22.0': 2,
#    'nan': 0,
#    '28.0': 2,
#    '26.0': 4,
#    '25.0': 4,
#    '29.0': 2,
#    '27.0': 3,
#    '24.0': 5,
#    '30.0': 1,
#    '21.0': 2,
#    '23.0': 1}},
#  {'igA1_1': {'20.1': 1,
#    '28.4': 1,
#    'nan': 0,
#    '26.7': 1,
#    '118.9': 1,
#    '24.1': 1,
#    '17.8': 1,
#    '12.4': 1,
#    '79.2': 1,
#    '16.3': 1,
#    '5.1': 1,
#    '19.7': 1,
#    '79.0': 1,
#    '52.6': 1,
#    '20.7': 1,
#    '53.1': 1,
#    '33.7': 1,
#    '10.6': 2,
#    '21.1': 1,
#    '54.6': 1,
#    '18.5': 1,
#    '28.6': 1,
#    '14.6': 1,
#    '38.3': 1,
#    '13.4': 1,
#    '22.2': 1,
#    '17.7': 1,
#    '25.6': 1,
#    '10.4': 1,
#    '83.7': 1}},
#  {'igA1_2': {'31.7': 1,
#    '19.4': 1,
#    'nan': 0,
#    '72.0': 1,
#    '7.0': 1,
#    '224.7': 1,
#    '108.5': 1,
#    '23.3': 1,
#    '36.4': 1,
#    '56.3': 1,
#    '36.1': 1,
#    '26.5': 1,
#    '37.8': 1,
#    '33.3': 1,
#    '25.1': 1,
#    '58.1': 1,
#    '11.2': 1,
#    '7.7': 1,
#    '27.0': 1,
#    '33.4': 1,
#    '30.7': 1,
#    '16.6': 1,
#    '18.1': 1,
#    '111.1': 1,
#    '21.3': 1,
#    '10.9': 1,
#    '17.2': 1,
#    '35.3': 1}},
#  {'igA2_1': {'23.5': 1,
#    '18.6': 1,
#    'nan': 0,
#    '21.6': 1,
#    '37.1': 1,
#    '35.0': 1,
#    '11.2': 1,
#    '25.9': 1,
#    '35.8': 1,
#    '15.7': 1,
#    '14.2': 1,
#    '82.7': 1,
#    '61.3': 1,
#    '17.9': 1,
#    '34.1': 1,
#    '36.0': 1,
#    '24.8': 1,
#    '44.0': 1,
#    '6.0': 1,
#    '19.3': 1,
#    '18.9': 1,
#    '13.5': 1,
#    '16.2': 1,
#    '9.7': 1,
#    '36.4': 1,
#    '43.5': 1,
#    '15.8': 1,
#    '13.7': 1,
#    '131.0': 1}},
#  {'wellbeing_recoded': {'1.0': 9, 'nan': 0, '0.0': 22}},
#  {'ads_m_i_pv': {'2.0': 6, '3.0': 15, 'nan': 0, '1.0': 1, '4.0': 3}},
#  {'ads_v_i_pv': {'3.0': 14, '4.0': 6, 'nan': 0, '2.0': 5}},
#  {'ads_ta_i_pv': {'2.0': 9, '3.0': 9, '1.0': 3, 'nan': 0, '4.0': 4}},
#  {'ads_sa_i_pv': {'3.0': 14, '4.0': 3, '2.0': 6, 'nan': 0, '0.0': 2}},
#  {'ads_a_i_pv': {'3.0': 11, '4.0': 10, 'nan': 0, '2.0': 3, '5.0': 1}},
#  {'ads_p_i_pv': {'1.0': 3, '2.0': 8, 'nan': 0, '3.0': 7, '0.0': 4, '4.0': 3}},
#  {'ads_m_i_pv_2': {'2.0': 6, '1.0': 16, 'nan': 0, '4.0': 3}},
#  {'ads_ta_i_pv_2': {'2.0': 9, '1.0': 12, 'nan': 0, '4.0': 4}},
#  {'ads_a_i_pv_2': {'3.0': 11, '4.0': 11, 'nan': 0, '2.0': 3}},
#  {'ads_m_i_pv_2_r': {'0.0': 22, 'nan': 0, '1.0': 3}},
#  {'ads_v_i_pv_r': {'1.0': 20, 'nan': 0, '0.0': 5}},
#  {'ads_ta_i_pv_2_r': {'0.0': 21, 'nan': 0, '1.0': 4}},
#  {'ads_sa_i_pv_r': {'1.0': 17, '0.0': 6, 'nan': 0, '99.0': 2}},
#  {'ads_a_i_pv_2_r': {'1.0': 22, 'nan': 0, '0.0': 3}},
#  {'ads_p_i_pv_r': {'0.0': 11, 'nan': 0, '1.0': 10, '99.0': 4}},
#  {'countinsecurei_2020': {'3': 6,
#    '4': 3,
#    '999': 10,
#    '2': 9,
#    '5': 2,
#    '1': 4,
#    '6': 1}},
#  {'countsecurei_2020': {'3': 9,
#    '2': 4,
#    '999': 10,
#    '4': 6,
#    '1': 2,
#    '5': 3,
#    '0': 1}},
#  {'ADS2i_2020': {'0': 13, '999': 10, '1': 12}},
#  {'id_name': {'Maximiliano-Cárdenas-Catelicán': 1,
#    'Martín-Pérez-González': 1,
#    'Noemí-Cárdenas-Gutierrez': 1,
#    'Jasna-Mansilla-Mansilla': 1,
#    'Jhampiere-Largacha-Yañez': 1,
#    'Antonella-Melián-Ruiz': 1,
#    'Agustina-Bachmann-Sánchez': 1,
#    'Daniela-Cárdenas-Bon': 1,
#    'Danna-Merkle-Vargas': 1,
#    'Constanza-Uribe-Alvarado': 1,
#    'Francisca-Ulloa-Hermosilla': 1,
#    'Jennedith-Soto-Godoy': 1,
#    'Jorge-Muñoz-Vera': 1,
#    'María-Levet-Espinoza': 1,
#    'Damaris-Parra-Hernández': 1,
#    'Danae-Canto-Saldivia': 1,
#    'Isabella-Oyarzún-Villalobos': 1,
#    'Maura-González-Silva': 1,
#    'Dariel-Ampuero-Chaura': 1,
#    'Ihan-Otavo-Hernández': 1,
#    'Felipe-Fernández-Ampuero': 1,
#    'Amaro-Jañas-Cordero': 1,
#    'Dalila-Alarcón-Gallardo': 1,
#    'Martin-Correa-González': 1,
#    'Florencia-Maldonado-Ampuero': 1,
#    'Francisco-Veloso-Aguila': 1,
#    'Cristobal-Salazar-Muñoz': 1,
#    'Javier-Rojas-Vera': 1,
#    'Emily-Mancilla-Ojeda': 1,
#    'Alvaro-Guzmán-Jara': 1,
#    'Juan-Navarro-Alvarez': 1,
#    'Amaia-Varas-Vito': 1,
#    'José-Santos-Ramírez': 1,
#    'Pilar-Catalán-Olila': 1,
#    'Evolet-Cardozo-Legüe': 1}}]

# %%
with open("../raw_data_spss/desc_columns.json", 'r', encoding="utf-8") as doc_open:
    data_description = json.load(doc_open)

# %%
def search_colum_in_dict(name_key, dict_values):
    response = None
    stop_condition = 0

    for element in dict_values:
        if stop_condition == 1:
            break

        for key in element:
            if key == name_key:
                response = element[key]
                stop_condition = 1
                break

    return response

# %%
for element in data_description:
    for key in element:
        print(key)
    break
# Out:
# Observador_1

# %%
columns_with_none = []

for column in df_with_values_to_cluster.columns:
    if column not in ['id_name', 'm1', 'm2', 'm3', 'm4', 'N°_diada', 'Fe']:
        value_response = search_colum_in_dict(column, data_description)
        if value_response == None:
            columns_with_none.append(column)

len(columns_with_none)
# Out:
# 153

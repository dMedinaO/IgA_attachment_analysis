# %%
import pandas as pd

df_data = pd.read_excel("../data_to_work_dm_12042022/Base de datos 13.10.2017 - _MAN_actualizado 19.10.17.xlsx", sheet_name="Update-2", skiprows=1)
df_data
# Out:
#     ID MUESTRA       NOMBRE APELLIDO PATERNO APELLIDO MATERNO     [ug/ml]  \
# 0        001-1  Maximiliano         Cárdenas        Catelicán   20.076728
# 1        001-2  Maximiliano         Cárdenas        Catelicán   31.719207
# 2        001-3  Maximiliano         Cárdenas        Catelicán   23.453752
# 3        001-4  Maximiliano         Cárdenas        Catelicán   25.016903
# 4        004-1       Martín            Pérez         González   28.584920
# ..         ...          ...              ...              ...         ...
# 132      065-4        Pilar          Catalán            Olila   24.854455
# 133      066-1       Evolet          Cardozo            Legüe   83.680568
# 134      066-2       Evolet          Cardozo            Legüe   35.309869
# 135      066-3       Evolet          Cardozo            Legüe  156.480231
# 136      066-4       Evolet          Cardozo            Legüe  176.466167
#
#      Flag  Dilution      [450]        MAX        MIN  ...  \
# 0    PASS       5.0   4.015346   6.616227        NaN  ...
# 1    PASS       5.0   6.343841   9.948513   3.521333  ...
# 2    PASS       5.0   4.690750   7.594311   2.463598  ...
# 3    PASS       5.0   5.003381   8.043302   2.659766  ...
# 4    PASS       5.0   5.716984   9.061069   3.114614  ...
# ..    ...       ...        ...        ...        ...  ...
# 132  PASS       1.0  24.854455  56.082239   9.066338  ...
# 133  PASS       5.0  16.736114  20.155173  13.702322  ...
# 134  PASS       5.0   7.061974   8.818623   5.493324  ...
# 135  PASS       5.0  31.296046  21.810159   0.599694  ...
# 136  PASS       5.0  35.293233  24.684455   0.584556  ...
#
#      B/BO MEDIDO 450 NM.1  CONCENTRACIÓN 450 NM  OD1 492 NM  OD2 492 NM  \
# 0                0.906645              4.164252         NaN         NaN
# 1                0.841147              9.944393         NaN         NaN
# 2                0.884381              6.055710         NaN         NaN
# 3                0.875141              6.861995         NaN         NaN
# 4                0.856047              8.570093         NaN         NaN
# ..                    ...                   ...         ...         ...
# 132              0.661132             35.695335      0.1449     0.12210
# 133              0.655830              0.655830      0.1968     0.26560
# 134              0.763820              0.763820      0.2551     0.27330
# 135              0.599694              0.198700      0.2319     0.21530
# 136              0.584556              0.185800      0.2345     0.21015
#
#      PROMEDIO OD 492 NM  B/BO MEDIDO A 492 NM  CONCENTRACIÓN 492 NM  \
# 0                   NaN                   NaN                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4                   NaN                   NaN                   NaN
# ..                  ...                   ...                   ...
# 132            0.133500              0.741255             33.080489
# 133            0.231200              0.691698              0.691698
# 134            0.264200              0.790426              0.790426
# 135            0.644129              0.644129                   NaN
# 136            0.628721              0.628721                   NaN
#
#                OBSERVACION 1  OBSERVACION 2  % CV OD450 NM
# 0    OD MEDIDA SOLO A 450 NM            NaN       1.696570
# 1    OD MEDIDA SOLO A 450 NM            NaN       1.054782
# 2    OD MEDIDA SOLO A 450 NM            NaN       3.587601
# 3    OD MEDIDA SOLO A 450 NM            NaN       0.181822
# 4    OD MEDIDA SOLO A 450 NM            NaN       0.704096
# ..                       ...            ...            ...
# 132                      NaN            NaN       0.620655
# 133                      NaN            NaN       4.093375
# 134                      NaN            NaN       5.826684
# 135                      NaN        0.56735            NaN
# 136                      NaN         0.6052            NaN
#
# [137 rows x 24 columns]

# %%
matrix_data = []

for column in df_data.columns:
    count_null = df_data[column].isna().sum()
    percentage = count_null/len(df_data)*100
    row = [column, count_null, percentage]
    matrix_data.append(row)

df_summary = pd.DataFrame(matrix_data, columns=['columna', 'count', 'percentage'])
df_summary = df_summary.sort_values(by=['percentage'], ascending=False)
df_summary
# Out:
#                  columna  count  percentage
# 22         OBSERVACION 2    132   96.350365
# 21         OBSERVACION 1    100   72.992701
# 20  CONCENTRACIÓN 492 NM     39   28.467153
# 19  B/BO MEDIDO A 492 NM     37   27.007299
# 18    PROMEDIO OD 492 NM     37   27.007299
# 17            OD2 492 NM     37   27.007299
# 16            OD1 492 NM     37   27.007299
# 9                    MIN     31   22.627737
# 23         % CV OD450 NM      6    4.379562
# 15  CONCENTRACIÓN 450 NM      5    3.649635
# 13    PROMEDIO OD 450 NM      4    2.919708
# 14  B/BO MEDIDO 450 NM.1      4    2.919708
# 12            OD2 450 NM      4    2.919708
# 11            OD1 450 NM      4    2.919708
# 10    B/BO MEDIDO 450 NM      4    2.919708
# 8                    MAX      4    2.919708
# 7                  [450]      4    2.919708
# 6               Dilution      4    2.919708
# 1                 NOMBRE      0    0.000000
# 5                   Flag      0    0.000000
# 4                [ug/ml]      0    0.000000
# 3       APELLIDO MATERNO      0    0.000000
# 2       APELLIDO PATERNO      0    0.000000
# 0             ID MUESTRA      0    0.000000

# %%
columns_to_plot = ['[ug/ml]',
'Dilution',                 
'[450]',  
'MAX',    
'MIN',    
'B/BO MEDIDO 450 NM',       
'OD1 450 NM',               
'OD2 450 NM',               
'PROMEDIO OD 450 NM',       
'B/BO MEDIDO 450 NM.1',     
'CONCENTRACIÓN 450 NM',     
'OD1 492 NM',               
'OD2 492 NM',               
'PROMEDIO OD 492 NM',       
'B/BO MEDIDO A 492 NM',     
'CONCENTRACIÓN 492 NM',          
'% CV OD450 NM']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.style.use("seaborn-v0_8-white")
plt.rc('axes', grid=False, facecolor="white")
plt.rcParams.update({'font.size': 14})

fig, axes = plt.subplots(3, 6, figsize=(20, 12))

i = 0
j = 0
index =0

for column in columns_to_plot:
    index+=1
    sns.boxplot(ax=axes[i][j], x=df_data[column])

    if index == 6 or index==12:
        i += 1
        j = 0
    else:
        j+=1
